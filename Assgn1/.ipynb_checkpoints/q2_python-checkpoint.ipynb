# %%
import math
array = []
array.append(0.2)

# %%
pi = math.acos(-1)

# %%
for i in range(1,1000):
    array.append(((array[i-1] + pi)*100) - (int)((array[i-1] + pi)*100))
    print("%.4f" %array[i])
# Out:
# 0.1593
# 0.0858
# 0.7394
# 0.0984
# 0.9963
# 0.7896
# 0.1154
# 0.6964
# 0.8029
# 0.4540
# 0.5602
# 0.1808
# 0.2372
# 0.8794
# 0.1018
# 0.3353
# 0.6935
# 0.5089
# 0.0519
# 0.3488
# 0.0363
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# 0.7863
# ...
